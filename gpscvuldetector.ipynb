# %%
# !ls
# %cd lib
# Out:
# __notebook__.ipynb

# %%
# !rm -rf  GPSCVulDetector

# %%
# %cd ..
# Out:
# /kaggle

# %%
# !git clone  https://github.com/MEHALSAKTHI/GPSCVulDetector.git
# Out:
# Cloning into 'GPSCVulDetector'...
# remote: Enumerating objects: 1764, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Total 1764 (delta 13), reused 13 (delta 13), pack-reused 1750
# Receiving objects: 100% (1764/1764), 8.99 MiB | 16.15 MiB/s, done.
# Resolving deltas: 100% (438/438), done.

# %%
# !ls
# Out:
# GPSCVulDetector  input	lib  src  working

# %%
# %cd GPSCVulDetector/
# Out:
# /kaggle/GPSCVulDetector

# %%
# !ls
# Out:
# CGEVulDetector.py  graph_extractor_example  pattern_extractor_example
# PFExtractor.py	   graph_feature	    pattern_feature
# README.md	   models		    preprocessing.py
# data		   parser.py

# %%
# !python CGEVulDetector.py
# Out:
# 2022-11-09 17:56:38.706927: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input1 (InputLayer)             [(None, 1, 250)]     0
# __________________________________________________________________________________________________
# input2 (InputLayer)             [(None, 3, 250)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1, 200)       150200      input1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 3, 200)       150200      input2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 1, 200)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1, 200)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 400)       0           max_pooling1d[0][0]
#                                                                  max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 100)       40100       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 50)        5050        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 10)        510         dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1, 1)         11          dense_2[0][0]
# ==================================================================================================
# Total params: 346,071
# Trainable params: 346,071
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-11-09 17:56:39.276153: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 168/168 [==============================] - 2s 7ms/step - loss: 0.2673 - accuracy: 0.8827
# Epoch 2/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.1578 - accuracy: 0.9402
# Epoch 3/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.1114 - accuracy: 0.9593
# Epoch 4/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0977 - accuracy: 0.9651
# Epoch 5/100
# 168/168 [==============================] - 2s 9ms/step - loss: 0.0977 - accuracy: 0.9645
# Epoch 6/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0896 - accuracy: 0.9656
# Epoch 7/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0878 - accuracy: 0.9671
# Epoch 8/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0873 - accuracy: 0.9658
# Epoch 9/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0826 - accuracy: 0.9686
# Epoch 10/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0862 - accuracy: 0.9666
# Epoch 11/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0848 - accuracy: 0.9666
# Epoch 12/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0807 - accuracy: 0.9680
# Epoch 13/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0782 - accuracy: 0.9701
# Epoch 14/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0857 - accuracy: 0.9666
# Epoch 15/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0777 - accuracy: 0.9677
# Epoch 16/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0769 - accuracy: 0.9703
# Epoch 17/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0771 - accuracy: 0.9684
# Epoch 18/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0768 - accuracy: 0.9707
# Epoch 19/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0734 - accuracy: 0.9716
# Epoch 20/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0773 - accuracy: 0.9692
# Epoch 21/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0736 - accuracy: 0.9731
# Epoch 22/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0646 - accuracy: 0.9751
# Epoch 23/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0655 - accuracy: 0.9746
# Epoch 24/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0666 - accuracy: 0.9712
# Epoch 25/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0641 - accuracy: 0.9742
# Epoch 26/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0606 - accuracy: 0.9750
# Epoch 27/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0639 - accuracy: 0.9759
# Epoch 28/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0552 - accuracy: 0.9806
# Epoch 29/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0603 - accuracy: 0.9765
# Epoch 30/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.
100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 0.9981
# Epoch 89/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0135 - accuracy: 0.9961
# Epoch 90/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0045 - accuracy: 0.9993
# Epoch 91/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0104 - accuracy: 0.9970
# Epoch 92/100
# 168/168 [==============================] - 1s 6ms/step - loss: 0.0226 - accuracy: 0.9938
# Epoch 93/100
# 168/168 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 94/100
# 168/168 [==============================] - 1s 7ms/step - loss: 4.3330e-04 - accuracy: 1.0000
# Epoch 95/100
# 168/168 [==============================] - 1s 7ms/step - loss: 2.1875e-04 - accuracy: 1.0000
# Epoch 96/100
# 168/168 [==============================] - 1s 7ms/step - loss: 8.0503e-05 - accuracy: 1.0000
# Epoch 97/100
# 168/168 [==============================] - 1s 7ms/step - loss: 6.7657e-05 - accuracy: 1.0000
# Epoch 98/100
# 168/168 [==============================] - 1s 7ms/step - loss: 3.8383e-05 - accuracy: 1.0000
# Epoch 99/100
# 168/168 [==============================] - 1s 6ms/step - loss: 3.3695e-05 - accuracy: 1.0000
# Epoch 100/100
# 168/168 [==============================] - 1s 7ms/step - loss: 3.1952e-05 - accuracy: 1.0000
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3411 - accuracy: 0.9610
# Loss:  0.34114447236061096 Accuracy:  0.9609609842300415
# Accuracy:  0.960960960960961
# False positive rate(FPR):  0.05909090909090909
# False negative rate(FNR):  0.0
# Recall(TPR):  1.0
# Precision:  0.8968253968253969
# F1 score:  0.9456066945606695

# %%
# !ls
# Out:
# CGEVulDetector.py  data			    parser.py
# PFExtractor.py	   graph_extractor_example  pattern_extractor_example
# README.md	   graph_feature	    pattern_feature
# __pycache__	   models		    preprocessing.py

# %%
# %cd pattern_extractor_example
# Out:
# /kaggle/GPSCVulDetector/pattern_extractor_example

# %%
# !ls
# Out:
# PatternExtract_IF.py  PatternExtract_RE.py  PatternExtract_TS.py

# %%
# !python PatternExtract_IF.py
# Out:
# loopfallback3333.c
# [1, 0, 0, 0]
# while3.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call99.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# while5555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while77.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback2.c
# [0, 0, 0, 0]
# for6666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while111.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback8.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# while6666.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback44.c
# [1, 0, 1, 0]
# while11.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call5555.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile3333.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile77777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call2.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfor2.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfor33.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while22222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while4444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call222.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# function_call5.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfunction_call4.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call1.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfunction_call55.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor66.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile6666.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback1.c
# [1, 0, 0, 0]
# function_call555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor444.c
# [1, 0, 1, 0]
# function_call55.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call2222.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback222.c
# [1, 0, 0, 0]
# loopwhile22222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback7777.c
# [1, 0, 0, 0]
# while44.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback666.c
# [1, 0, 0, 0]
# loopfor8888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback11111.c
# [1, 0, 0, 0]
# for22222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback33333.c
# [1, 0, 0, 0]
# while77777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while66.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call7.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for33.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback4444.c
# [1, 0, 1, 0]
# loopwhile7777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call66666.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call6.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# fallback4.c
# [1, 0, 1, 0]
# fallback111.c
# [0, 0, 0, 0]
# function_call1.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# for2222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call8888.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call3.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfallback33.c
# [1, 0, 0, 0]
# fallback22222.c
# [0, 0, 0, 0]
# fallback333.c
# [1, 0, 0, 0]
# loopfallback6666.c
# [1, 0, 0, 0]
# while22.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor3333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call99.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfunction_call8.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor7.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile66666.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call77.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor44444.c
# [1, 0, 1, 0]
# function_call4444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor22.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback2.c
# [1, 0, 0, 0]
# loopfor888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while33333.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback8888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor55555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback8_attack.c
# [0, 0, 0, 0]
# loopfor77.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call55555.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback777.c
# [1, 0, 0, 0]
# while666.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call5.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# while444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while6.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback5555.c
# [1, 0, 0, 1]
# loopwhile555.c
# There is no fallback funnction!
# [0, 1, 0, 1]
# loopfunction_call66.c
# There is no fallback funnction!
# [0, 1, 0, 1]
# loopfallback111.c
# [1, 0, 0, 0]
# function_call6666.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call1111.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# while2.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback222.c
# [0, 0, 0, 0]
# for66.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for7777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor44.c
# [1, 0, 1, 0]
# fallback8888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile333.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call7.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call333.c
# [0, 0, 0, 0]
# function_call44444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback55555.c
# [1, 0, 0, 1]
# loopfunction_call6.c
# [0, 0, 0, 0]
# loopfallback22.c
# [1, 0, 0, 0]
# loopfunction_call44.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback5555.c
# [1, 0, 0, 1]
# for22.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call22.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfunction_call444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call44.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback44444.c
# [1, 0, 1, 0]
# for88.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call22222.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback4444.c
# [1, 0, 1, 0]
# fallback666.c
# [1, 0, 0, 0]
# loopwhile11111.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback77777.c
# [1, 0, 0, 0]
# loopfallback6.c
# [1, 0, 0, 0]
# for33333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback1111.c
# [1, 0, 0, 0]
# for1.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile44444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor111.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call66.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback555.c
# [1, 0, 0, 1]
# fallback1111.c
# [0, 0, 0, 0]
# while1111.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call11.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopwhile1.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor22222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback6.c
# [1, 0, 0, 0]
# function_call33333.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback3.c
# [1, 0, 0, 0]
# loopwhile33.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# while2222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for2.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# vntlib.h
# There is no fallback funnction!
# [0, 1, 0, 0]
# for11.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback7.c
# [1, 0, 0, 0]
# for8888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile1111.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call77777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile3.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor66666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile44.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile5.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call33.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile33333.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback11.c
# [1, 0, 0, 0]
# fallback1.c
# [1, 0, 0, 0]
# function_call8.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback7.c
# [1, 0, 0, 0]
# loopfor6666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while5.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile2222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback77.c
# [1, 0, 0, 0]
# function_call222.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# while44444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call88.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call9999.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback7777.c
# [1, 0, 0, 0]
# loopfor4.c
# [1, 0, 1, 0]
# fallback22.c
# [0, 0, 0, 0]
# loopfunction_call9.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfunction_call555.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor1.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfor4444.c
# [1, 0, 1, 0]
# fallback444.c
# [1, 0, 1, 0]
# while777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while7777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for44444.c
# [1, 0, 1, 0]
# function_call88888.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while333.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback55.c
# [1, 0, 0, 1]
# loopfor55.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfallback88_Attack.c
# [0, 0, 0, 0]
# loopfallback44.c
# [1, 0, 1, 0]
# while4.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback444.c
# [1, 0, 1, 0]
# while3333.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile66.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while7.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while55555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile_loop.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for3333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call11.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call9.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor7777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile4444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call33.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# for777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback777.c
# [1, 0, 0, 0]
# fallback11.c
# [1, 0, 0, 0]
# loopfallback4.c
# [1, 0, 1, 0]
# while222.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback333.c
# [1, 0, 0, 0]
# while33.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call999.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call11111.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopwhile444.c
# There is no fallback funnction!
# [0, 1, 0, 1]
# for66666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call3333.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call4.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call111.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# function_call99999.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfallback66.c
# [1, 0, 0, 0]
# loopfor33333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for3.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile4.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for88888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for111.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopwhile2.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for55555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback8.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# fallback33.c
# [1, 0, 0, 0]
# loopfor777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for1111.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback555.c
# [1, 0, 0, 1]
# loopwhile666.c
# There is no fallback funnction!
# [0, 1, 0, 1]
# loopfunction_call777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor88.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback77.c
# [1, 0, 0, 0]
# for333.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call7777.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor5555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback2222.c
# [1, 0, 0, 0]
# while1.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback8_Attack.c
# [0, 0, 0, 0]
# for7.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback55555.c
# [1, 0, 0, 1]
# loopfunction_call666.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# for5.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for4.c
# [1, 0, 1, 0]
# loopfor6.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback22222.c
# [1, 0, 0, 0]
# for77.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback3.c
# [1, 0, 0, 0]
# loopwhile7.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# function_call2.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor3.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for6.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for4444.c
# [1, 0, 1, 0]
# loopfallback88.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# fallback77777.c
# [1, 0, 0, 0]
# loopfallback55.c
# [1, 0, 0, 1]
# loopfor2222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for77777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# while66666.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile55555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback88888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# fallback2222.c
# [0, 0, 0, 0]
# loopfor222.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call3.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor8.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# function_call444.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# for8.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for55.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# fallback888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# fallback44444.c
# [1, 0, 1, 0]
# loopwhile77.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile5555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfallback88888.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# for444.c
# [1, 0, 1, 0]
# loopfunction_call88.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile11.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor5.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# for11111.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfallback11111.c
# [1, 0, 0, 0]
# fallback3333.c
# [1, 0, 0, 0]
# loopfunction_call999.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# for44.c
# [1, 0, 1, 0]
# fallback6666.c
# [1, 0, 0, 0]
# function_call666.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# loopfor88888.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfor77777.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfunction_call22.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfallback5.c
# [1, 0, 0, 1]
# function_call888.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile6.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfunction_call888.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while555.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile111.c
# There is no fallback funnction!
# [0, 1, 0, 1]
# loopfunction_call333.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfunction_call77.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile22.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# while55.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopwhile55.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# fallback66.c
# [1, 0, 0, 0]
# fallback88.c
# There is no fallback funnction!
# [0, 0, 0, 0]
# for5555.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback66666.c
# [1, 0, 0, 0]
# loopfallback66666.c
# [1, 0, 0, 0]
# while11111.c
# There is no fallback funnction!
# [0, 0, 0, 1]
# loopfor11111.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# fallback5.c
# [1, 0, 0, 1]
# loopfor666.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfor11.c
# There is no fallback funnction!
# [0, 0, 1, 0]
# loopfunction_call111.c
# There is no fallback funnction!
# [0, 1, 0, 0]
# loopfor1111.c
# There is no fallback funnction!
# [0, 0, 1, 0]

# %%
# !python PatternExtract_RE.py
# Out:
# 39890.sol
# 38888.sol
# 22416.sol
# SimpleDAO.sol
# 14758.sol
# 4679.sol
# Reentrance_exploit.sol
# 24007.sol
# Reentrance_02.sol
# 9611.sol
# 19402.sol
# 39817.sol
# 774.sol
# 14353.sol
# 3270.sol
# 37891.sol
# 39664.sol
# 12182.sol
# 30178.sol
# 34577.sol
# 33851.sol
# 33450.sol
# 27486.sol
# 14994.sol
# 4472.sol
# 1123.sol
# 40090.sol
# 39749.sol
# 40092.sol
# 39705.sol
# 3255.sol
# simple_dao_fixed.sol
# 35878.sol
# 36563.sol
# 10715.sol
# 17518.sol
# 23803.sol
# 9920.sol
# 19128.sol
# 39019.sol
# 37474.sol
# 40341.sol
# 27334.sol
# 1879.sol
# 33501.sol
# 1403.sol
# 40241.sol
# 33835.sol
# 11705.sol
# 23387.sol
# 18170.sol
# 28687.sol
# 14741.sol
# 17573.sol
# 11719.sol
# 27248.sol
# 29517.sol
# 3054.sol
# 27398.sol
# 13952.sol
# 35617.sol
# simple_dao.sol
# 14458.sol
# 36334.sol
# 14579.sol
# 30460.sol
# 23166.sol
# 35649.sol
# 39644.sol
# 2021.sol
# 21900.sol
# 40589.sol
# cross-function-reentrancy-fixed.sol
# 16057.sol
# 21755.sol
# 14945.sol
# 39326.sol
# 21999.sol
# 10107.sol
# 16925.sol
# 39269.sol
# 23421.sol
# 10297.sol
# 1710.sol
# 40425.sol
# 33410.sol
# 31912.sol
# Bank_attack.sol
# 32559.sol
# 37836.sol
# 30337.sol
# 22074.sol
# 2013.sol
# 28869.sol
# 16884.sol
# 7530.sol
# 21111.sol
# 27188.sol
# 39932.sol
# 9600.sol
# 32605.sol
# 26188.sol
# 22247.sol
# 36732.sol
# 39866.sol
# 29601.sol
# 25196.sol
# 9242.sol
# 7519.sol
# 1041.sol
# 22273.sol
# 10022.sol
# 8139.sol
# 1813.sol
# 1288.sol
# 16957.sol
# 10933.sol
# 10763.sol
# 11861.sol
# 1518.sol
# 1226.sol
# 7724.sol
# 8497.sol
# 12115.sol
# 6149.sol
# 11351.sol
# 6220.sol
# 12044.sol
# 11711.sol
# 10826.sol
# 9750.sol
# 11178.sol
# 9892.sol
# 28157.sol
# 9329.sol
# 17907.sol
# 10547.sol
# 6404.sol
# 1456.sol
# 22714.sol
# 7891.sol
# 9759.sol
# 739.sol
# 10831.sol
# 7775.sol
# 9309.sol
# 10559.sol
# 6753.sol
# 6348.sol
# 10758.sol
# 4699.sol
# 9987.sol
# 11128.sol
# 9998.sol
# 10129.sol
# 11526.sol
# 11539.sol
# 7214.sol
# 12075.sol
# 6806.sol
# 2821.sol
# 667.sol
# 5133.sol
# 18771.sol
# 5400.sol
# 6454.sol
# 11684.sol
# 10369.sol
# 15422.sol
# 6596.sol
# 33575.sol
# 11323.sol
# 9333.sol
# 10159.sol
# 7419.sol
# 5572.sol
# 11346.sol
# 11765.sol
# 11949.sol
# 11339.sol
# 11348.sol
# 6798.sol
# 9479.sol
# 22438.sol
# 8766.sol
# 4481.sol
# 16590.sol
# 10431.sol
# 5591.sol
# 7511.sol

# %%
# !ls
# Out:
# PatternExtract_IF.py  PatternExtract_RE.py  PatternExtract_TS.py

# %%
# %cd ..
# Out:
# /kaggle/GPSCVulDetector

# %%
# !ls
# Out:
# CGEVulDetector.py  data			    parser.py
# PFExtractor.py	   graph_extractor_example  pattern_extractor_example
# README.md	   graph_feature	    pattern_feature
# __pycache__	   models		    preprocessing.py

# %%
# %cd graph_extractor_example
# Out:
# /kaggle/GPSCVulDetector/graph_extractor_example

# %%
# !ls
# Out:
# Graph2Vec.py  GraphExtractor.py  vec2onehot.py

# %%
# !python GraphExtractor.py
# Out:
# function list [['function WithdrawReward(address recipient) public {', 'uint amountToWithdraw = rewardsForA[recipient];', 'rewardsForA[recipient] = 0;', 'require(recipient.call.value(amountToWithdraw)());', '}'], ['function GetFirstWithdrawalBonus(address recipient) public {', 'if (claimedBonus[recipient] == false) {', 'throw;', '}', 'rewardsForA[recipient] += 100;', 'WithdrawReward(recipient);', 'claimedBonus[recipient] = true;', '}', '}']]
# node_feature [['C0', 'C0', 'NoLimit', ['NULL'], 0, 'NULL'], ['S', 'S', 'NoLimit', ['W0'], 2, 'MSG'], ['VAR0', 'VAR0', 'W0', 1, 'ASSIGN'], ['VAR1', 'VAR1', 'W0', 1, 'ASSIGN'], ['W0', 'W0', 'NoLimit', ['C0'], 1, 'NULL'], ['F', 'F', 'NoLimit', ['S'], 0, 'MSG']]
# edge_feature [['C0', 'W0', 'C0', 1, 'FW'], ['W0', 'VAR0', 'W0', 1, 'FW'], ['VAR1', 'S', 'W0', 2, 'RG'], ['S', 'F', 'S', 0, 'FW'], ['F', 'W0', 'F', 1, 'FW']]
