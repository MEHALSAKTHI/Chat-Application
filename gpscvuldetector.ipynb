# %%
# !ls
# %cd lib
# Out:
# __notebook_source__.ipynb

# %%
# !rm -rf  GPSCVulDetector

# %%
# %cd ..

# %%
# !git clone  https://github.com/MEHALSAKTHI/GPSCVulDetector.git
# Out:
# Cloning into 'GPSCVulDetector'...
# remote: Enumerating objects: 1787, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 1787 (delta 20), reused 13 (delta 13), pack-reused 1750
# Receiving objects: 100% (1787/1787), 9.00 MiB | 5.45 MiB/s, done.
# Resolving deltas: 100% (445/445), done.

# %%
# !ls
# Out:
# GPSCVulDetector  __notebook_source__.ipynb

# %%
# %cd GPSCVulDetector/
# Out:
# /kaggle/working/GPSCVulDetector

# %%
# !ls
# Out:
# CGEVulDetector.py  graph_extractor_example  pattern_extractor_example
# PFExtractor.py	   graph_feature	    pattern_feature
# README.md	   models		    preprocessing.py
# data		   parser.py

# %%
# !python CGEVulDetector.py
# Out:
# CGEVulDetector
# Y_Train:
# [0 0 0 ... 0 0 0]
# [0.76457143 1.44492441]
# 2022-11-23 13:55:56.275614: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input1 (InputLayer)             [(None, 1, 250)]     0
# __________________________________________________________________________________________________
# input2 (InputLayer)             [(None, 3, 250)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1, 200)       150200      input1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !ls

# %%
# %cd pattern_extractor_example
# Out:
# /kaggle/working/GPSCVulDetector/pattern_extractor_example

# %%
# !ls

# %%
# !python PatternExtract_IF.py

# %%
# !python PatternExtract_RE.py

# %%
# !python PatternExtract_TS.py

# %%
# !ls

# %%
# %cd ..

# %%
# !ls

# %%
# %cd graph_extractor_example

# %%
# !ls

# %%
# !python GraphExtractor.py

# %%
# !grep "pattern_feature_extract"
